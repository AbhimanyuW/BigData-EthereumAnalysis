# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/home/jovyan/teaching_material/ECS765P/Coursework/PartD/GasGuzzlers/avg_gasused_mod.csv')

# %%
df1.columns = ['Date', 'Average gas used each month']

# %%
df1.head()
# Out:
#          Date  Average gas used each month
# 0  "01/2017"                   58527.96718
# 1  "01/2018"                   73576.14589
# 2  "01/2019"                   70250.64997
# 3  "02/2016"                  304524.23120
# 4  "02/2017"                   79977.49781

# %%
plt.figure(figsize = (20,10))
plt.xticks(rotation=90)
plt.xlabel('Month/Year')
plt.ylabel('Average gas used each month')
x=df1['Date']
y=df1['Average gas used each month']
plt.plot(x,y,color='crimson')

# %%
df1['Average gas used each month']
# Out:
# 0     5.852797e+04
# 1     7.357615e+04
# 2     7.025065e+04
# 3     3.045242e+05
# 4     7.997750e+04
# 5     7.804717e+04
# 6     2.338062e+05
# 7     7.045276e+04
# 8     7.353217e+04
# 9     4.233925e+05
# 10    8.294525e+04
# 11    7.326158e+04
# 12    7.227421e+05
# 13    7.678198e+04
# 14    7.031682e+04
# 15    3.472637e+05
# 16    1.136770e+05
# 17    7.706443e+04
# 18    1.785566e+05
# 19    1.194139e+05
# 20    7.182212e+04
# 21    3.647744e+05
# 22    1.032011e+05
# 23    1.143275e+05
# 24    7.165029e+04
# 25    6.074794e+05
# 26    1.083711e+05
# 27    1.223017e+05
# 28    7.034557e+04
# 29    1.064342e+06
# 30    1.251956e+05
# 31    1.115276e+05
# 32    7.135260e+04
# 33    5.526641e+05
# 34    8.480838e+04
# 35    1.181440e+05
# 36    7.346669e+04
# 37    4.459484e+05
# 38    6.918403e+04
# 39    9.348931e+04
# 40    7.331893e+04
# Name: Average gas used each month, dtype: float64
