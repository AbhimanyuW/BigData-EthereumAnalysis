# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/home/jovyan/teaching_material/ECS765P/Coursework/PartD/GasGuzzlers/avg_gas_mod.csv')

# %%
df1.columns = ['Date', 'Average gas price each month']

# %%
df1.head()
# Out:
#         Date  Average gas price each month
# 0  "01/2017"                  2.250757e+10
# 1  "01/2018"                  5.210606e+10
# 2  "01/2019"                  1.395446e+10
# 3  "02/2016"                  6.918068e+10
# 4  "02/2017"                  2.304723e+10

# %%
plt.figure(figsize = (20,10))
plt.xticks(rotation=90)
plt.xlabel('Month/Year')
plt.ylabel('Average gas price each month')
x=df1['Date']
y=df1['Average gas price each month']
plt.plot(x,y,color='coral')

# %%
df1['Average gas price each month']
# Out:
# 0     2.250757e+10
# 1     5.210606e+10
# 2     1.395446e+10
# 3     6.918068e+10
# 4     2.304723e+10
# 5     2.363657e+10
# 6     3.279704e+10
# 7     2.323225e+10
# 8     1.554977e+10
# 9     2.336118e+10
# 10    2.235512e+10
# 11    1.315374e+10
# 12    2.374628e+10
# 13    2.357231e+10
# 14    1.742251e+10
# 15    2.302125e+10
# 16    3.019944e+10
# 17    1.653331e+10
# 18    2.262954e+10
# 19    2.546030e+10
# 20    2.750608e+10
# 21    1.597440e+11
# 22    2.239684e+10
# 23    2.590577e+10
# 24    1.848324e+10
# 25    5.651130e+10
# 26    2.527040e+10
# 27    3.067503e+10
# 28    1.521387e+10
# 29    5.390169e+10
# 30    3.211287e+10
# 31    1.749829e+10
# 32    1.452694e+10
# 33    5.360761e+10
# 34    2.463429e+10
# 35    1.531247e+10
# 36    1.603486e+10
# 37    5.589953e+10
# 38    5.031807e+10
# 39    3.343936e+10
# 40    1.633884e+10
# Name: Average gas price each month, dtype: float64
